# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/nyuad-cai/MedFuse.git
# Out:
# Cloning into 'MedFuse'...
# remote: Enumerating objects: 306, done.
# remote: Counting objects: 100% (169/169), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 306 (delta 93), reused 132 (delta 84), pack-reused 137 (from 1)
# Receiving objects: 100% (306/306), 17.64 MiB | 15.88 MiB/s, done.
# Resolving deltas: 100% (118/118), done.
# Filtering content: 100% (5/5), 998.72 MiB | 51.34 MiB/s, done.

# %%
# train the imaging model with 14 radiology labels.
# !sh /content/MedFuse/scripts/radiology/uni_cxr.sh
# Out:
# /content/MedFuse/fusion_main.py:7: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp
# ...

# %%
# train LSTM model for in-hospital-mortality task ## Stage1
# !sh /content/MedFuse/scripts/mortality/train/uni_all.sh
# Out:
# /content/MedFuse/fusion_main.py:7: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp
# ...

# %%
# med fuse for in hospital mortality
# !sh /content/MedFuse/scripts/mortality/train/medFuse.sh
# Out:
# /content/MedFuse/fusion_main.py:7: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp
# ...

# %%
# med fuse for phenotype task
# !sh /content/MedFuse/scripts/phenotyping/train/medFuse.sh
# Out:
# /content/MedFuse/fusion_main.py:7: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp
# Namespace(layer_after=4, layers=2, vision_num_classes=25, resize=256, crop=224, vision_backbone='resnet34', pretrained=False, eval=False, network=None, fusion_type='lstm', task='phenotyping', labels_set='pheno', data_ratio=1.0, mmtm_ratio=4, daft_activation='linear', fusion='joint', dim=256, depth=1, epochs=50, load_state=None, load_state_cxr=None, load_state_ehr=None, mode='train', batch_size=16, resume=False, dropout=0.3, num_classes=25, patience=15, rec_dropout=0.0, timestep=1.0, imputation='previous', lr=7e-05, align=0.0, data_pairs='partial_ehr_cxr', missing_token=None, beta_1=0.9, normalizer_state=None, ehr_data_dir='/content/MedFuse/Mimic4Data/data', cxr_data_dir='/content/MedFuse/physionet.org/files/mimic-cxr-jpg/2.0.0', save_dir='checkpoints/phenotyping/medFuse')
# ...

# %%
# !sh /content/MedFuse/scripts/mortality/eval/medFuse.sh
# Out:
# /content/MedFuse/fusion_main.py:7: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp
# ...

# %%
# !unzip "/content/drive/MyDrive/CS 598 DFLH - Final Project - Medfuse/01cxrdata/physionet.org.zip" -d "/content/drive/MyDrive/CS 598 DFLH - Final Project - Medfuse/03medfuse/"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/CS 598 DFLH - Final Project - Medfuse/03medfuse/__MACOSX/physionet.org/files/mimic-cxr-jpg/2.0.0/resized/._cdc9d1ed-44e560b9-567db13f-747df18c-6d763971.jpg
#   inflating: /content/drive/MyDrive/CS 598 DFLH - Final Project - Medfuse/03medfuse/physionet.org/files/mimic-cxr-jpg/2.0.0/resized/b9b407ae-61d7122d-33942b5d-f8487062-8601bd65.jpg
#   inflating: /content/drive/MyDrive/CS 598 DFLH - Final Project - Medfuse/03medfuse/__MACOSX/physionet.org/files/mimic-cxr-jpg/2.0.0/resized/._b9b407ae-61d7122d-33942b5d-f8487062-8601bd65.jpg
#   inflating: /content/drive/MyDrive/CS 598 DFLH - Final Project - Medfuse/03medfuse/physionet.org/files/mimic-cxr-jpg/2.0.0/resized/ec444a35-5e83466d-cafb4b73-bc8ef375-0abab265.jpg
# ...

# %%
# train LSTM model for phenotype task
# !sh /content/MedFuse/scripts/phenotyping/train/uni_all.sh
# Out:
# /content/MedFuse/fusion_main.py:7: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp
# ...
